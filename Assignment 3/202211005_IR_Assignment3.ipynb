# %% [markdown]
# # Assignment 3 : Document Retrieval and Evaluation
# ## Dreamy pujara - 202211005

# %% [markdown]
# ### Extracting files

# %%
# !pip install rarfile
# Out:
# Collecting rarfile
#   Downloading rarfile-4.0-py3-none-any.whl (28 kB)
# Installing collected packages: rarfile
# Successfully installed rarfile-4.0

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
import rarfile
import tarfile

main_path = "/content/drive/MyDrive/FIRE_Dataset_EN_2010.rar"
data_extracted = "/content/extracted_files"

if not os.path.exists(data_extracted):
    os.makedirs(data_extracted)

with rarfile.RarFile(main_path, 'r') as main_rar:
    main_rar.extractall(data_extracted)

for root, dirs, files in os.walk(data_extracted):
    for file in files:
        if file.lower().endswith('.tgz'):
            tgz_file_path = os.path.join(root, file)
            with tarfile.open(tgz_file_path, 'r:gz') as nested_tgz:
                nested_tgz.extractall(root)
            os.remove(tgz_file_path)

print("Extraction completed.")
# Out:
# Extraction completed.

# %%
import gzip
gz_file_path = '/content/extracted_files/FIRE_Dataset_EN_2010/en.qrels.76-125.2010.txt.gz'
extracted_file_path = '/content/extracted_files/FIRE_Dataset_EN_2010/en.qrels.76-125.2010.txt'
with gzip.open(gz_file_path, 'rb') as gz_file:
    with open(extracted_file_path, 'wb') as extracted_file:
        extracted_file.write(gz_file.read())

print("Extraction complete.")
# Out:
# Extraction complete.

# %% [markdown]
# ### Read the files using BeautifulSoup library, perform preprocessing steps

# %%
import os
import pandas as pd
from bs4 import BeautifulSoup

main_file_location = "/content/extracted_files/FIRE_Dataset_EN_2010/TELEGRAPH_UTF8"
corpus = {}

def extract_text_from_xml(xml_path):
    with open(xml_path, 'r', encoding='utf-8') as xml_file:
        soup = BeautifulSoup(xml_file, 'xml')
        text_elements = soup.find_all('TEXT')

        if text_elements:
            text = " ".join([elem.get_text() for elem in text_elements if elem.get_text()])
            return text.strip()
        else:
            return None

for root_dir, _, files in os.walk(main_file_location):
    for file in files:
        if file.endswith(".utf8"):

            xml_path = os.path.join(root_dir, file)
            doc_id = file
            doc_text = extract_text_from_xml(xml_path)

            if doc_text:

                corpus[doc_id] = doc_text

corpus_df = pd.DataFrame(corpus.items(), columns=["docno", "Text"])

# %%
corpus_df
# Out:
#                                        docno  \
# 0        1050702_calcutta_story_4937658.utf8
# 1        1050128_calcutta_story_4300622.utf8
# 2        1050731_calcutta_story_5055128.utf8
# 3        1050330_calcutta_story_4552367.utf8
# 4        1051102_calcutta_story_5425738.utf8
# ...                                      ...
# 125511          1041023_frontpage_index.utf8
# 125512  1041011_frontpage_story_3867944.utf8
# 125513          1040930_frontpage_index.utf8
# 125514  1040910_frontpage_story_3740017.utf8
# 125515  1041226_frontpage_story_4176083.utf8
#
#                                                      Text
# 0       The Telegraph - Calcutta : Metro\n\n The final...
# 1       The Telegraph - Calcutta : Metro\n\n ENGLISH\n...
# 2       The Telegraph - Calcutta : Metro\n\n Metro Rec...
# 3       The Telegraph - Calcutta : Metro\n\n An actor ...
# 4       The Telegraph - Calcutta : Metro\n\nGuide foxe...
# ...                                                   ...
# 125511               The Telegraph - Calcutta : Frontpage
# 125512  The Telegraph - Calcutta : Frontpage\n\n Manmo...
# 125513               The Telegraph - Calcutta : Frontpage
# 125514  The Telegraph - Calcutta : Frontpage\n\n Murde...
# 125515  The Telegraph - Calcutta : Frontpage\n\n Split...
#
# [125516 rows x 2 columns]

# %%
corpus_df['Text'][0]
# Out:
# 'The Telegraph - Calcutta : Metro\n\n The final journey\n\n Based on a novel by Kamal Kumar Mazumdar, Gobardanga Shilpayans production, Antarjali Jatra, is a commentary on the cruelty and barbarism that women were subjected to in olden days. Being staged as part of Hutch Odeon 2005, the ongoing theatre festival that aims to promote Calcutta?s cultural heritage, it is a heart-wrenching performance that evokes feelings of pity, compassion and outrage at the heinous practices that were committed against women in the name of religious customs and rituals. The play relates the story of Jashobati, a beautiful, young girl, who becomes a victim of the Hindu koulinya protha. Born into a poor family, her father is compelled to marry her off to an old, dying man, or else the bride?s family runs the risk of being ostracised for not following a custom (protha) believed to be sacrosanct by upper class Hindus. As his newly wed bride, Jashobati accompanies her groom to the riverside, waiting for him to die. Surprisingly, Baijunath, a dom at the burning ghat, is the only one to express any feeling of humanity at the poor girl?s fate. Direction: Ashis Chattopadhyay.\n\n Event: Play in Bengali, Antarjali Jatra, produced by Gobardanga Shilpayan\n\n When: Today at 6.30 pm\n\n Where: Rabindra Sadan'

# %%
import nltk
import re
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer

nltk.download('punkt')
nltk.download('stopwords')

stemmer = PorterStemmer()
stop_words = set(stopwords.words('english'))

def preprocess(text):

    processed_text = re.sub(r'[^\w\s]', ' ', text)
    processed_text = processed_text.lower()
    words = nltk.word_tokenize(processed_text)
    stemmed_words = [stemmer.stem(word) for word in words if word not in stop_words]
    processed_text = " ".join(stemmed_words)

    return processed_text
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
corpus_df['processed_text'] = corpus_df['Text'].apply(preprocess)

# %%
corpus_df['processed_text'][0]
# Out:
# 'telegraph calcutta metro final journey base novel kamal kumar mazumdar gobardanga shilpayan product antarjali jatra commentari cruelti barbar women subject olden day stage part hutch odeon 2005 ongo theatr festiv aim promot calcutta cultur heritag heart wrench perform evok feel piti compass outrag heinou practic commit women name religi custom ritual play relat stori jashobati beauti young girl becom victim hindu koulinya protha born poor famili father compel marri old die man els bride famili run risk ostracis follow custom protha believ sacrosanct upper class hindu newli wed bride jashobati accompani groom riversid wait die surprisingli baijunath dom burn ghat one express feel human poor girl fate direct ashi chattopadhyay event play bengali antarjali jatra produc gobardanga shilpayan today 6 30 pm rabindra sadan'

# %% [markdown]
# ### Index the documents using TF-IDF.

# %%
# !pip install python-terrier
# Out:
# Collecting python-terrier
#   Downloading python-terrier-0.9.2.tar.gz (104 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 104.4/104.4 kB 2.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from python-terrier) (1.23.5)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from python-terrier) (1.5.3)
# Collecting wget (from python-terrier)
#   Downloading wget-3.2.zip (10 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from python-terrier) (4.66.1)
# Collecting pyjnius>=1.4.2 (from python-terrier)
#   Downloading pyjnius-1.5.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 8.4 MB/s eta 0:00:00
# Collecting matchpy (from python-terrier)
#   Downloading matchpy-0.5.5-py3-none-any.whl (69 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.6/69.6 kB 7.7 MB/s eta 0:00:00
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from python-terrier) (1.2.2)
# Collecting deprecated (from python-terrier)
#   Downloading Deprecated-1.2.14-py2.py3-none-any.whl (9.6 kB)
# Collecting chest (from python-terrier)
#   Downloading chest-0.2.3.tar.gz (9.6 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from python-terrier) (1.10.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from python-terrier) (2.31.0)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from python-terrier) (1.3.2)
# Collecting nptyping==1.4.4 (from python-terrier)
#   Downloading nptyping-1.4.4-py3-none-any.whl (31 kB)
# Requirement already satisfied: more_itertools in /usr/local/lib/python3.10/dist-packages (from python-terrier) (10.1.0)
# Collecting ir_datasets>=0.3.2 (from python-terrier)
#   Downloading ir_datasets-0.5.5-py3-none-any.whl (318 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 318.0/318.0 kB 9.8 MB/s eta 0:00:00
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from python-terrier) (3.1.2)
# Requirement already satisfied: statsmodels in /usr/local/lib/python3.10/dist-packages (from python-terrier) (0.14.0)
# Collecting ir_measures>=0.3.1 (from python-terrier)
#   Downloading ir_measures-0.3.3.tar.gz (48 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.8/48.8 kB 4.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting dill (from python-terrier)
#   Downloading dill-0.3.7-py3-none-any.whl (115 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.3/115.3 kB 10.4 MB/s eta 0:00:00
# Collecting pytrec_eval_terrier>=0.5.3 (from python-terrier)
#   Downloading pytrec_eval_terrier-0.5.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (287 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 287.4/287.4 kB 9.9 MB/s eta 0:00:00
# Collecting typish>=1.7.0 (from nptyping==1.4.4->python-terrier)
#   Downloading typish-1.9.3-py3-none-any.whl (45 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.1/45.1 kB 4.3 MB/s eta 0:00:00
# Requirement already satisfied: beautifulsoup4>=4.4.1 in /usr/local/lib/python3.10/dist-packages (from ir_datasets>=0.3.2->python-terrier) (4.11.2)
# Collecting inscriptis>=2.2.0 (from ir_datasets>=0.3.2->python-terrier)
#   Downloading inscriptis-2.3.2-py3-none-any.whl (41 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.2/41.2 kB 3.3 MB/s eta 0:00:00
# Requirement already satisfied: lxml>=4.5.2 in /usr/local/lib/python3.10/dist-packages (from ir_datasets>=0.3.2->python-terrier) (4.9.3)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.10/dist-packages (from ir_datasets>=0.3.2->python-terrier) (6.0.1)
# Collecting trec-car-tools>=2.5.4 (from ir_datasets>=0.3.2->python-terrier)
#   Downloading trec_car_tools-2.6-py3-none-any.whl (8.4 kB)
# Collecting lz4>=3.1.10 (from ir_datasets>=0.3.2->python-terrier)
#   Downloading lz4-4.3.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 13.0 MB/s eta 0:00:00
# Collecting warc3-wet>=0.2.3 (from ir_datasets>=0.3.2->python-terrier)
#   Downloading warc3_wet-0.2.3-py3-none-any.whl (13 kB)
# Collecting warc3-wet-clueweb09>=0.2.5 (from ir_datasets>=0.3.2->python-terrier)
#   Downloading warc3-wet-clueweb09-0.2.5.tar.gz (17 kB)
#   Preparing metadata (setup.py) ... done
# Collecting zlib-state>=0.1.3 (from ir_datasets>=0.3.2->python-terrier)
#   Downloading zlib-state-0.1.5.tar.gz (9.4 kB)
#   Preparing metadata (setup.py) ... done
# Collecting ijson>=3.1.3 (from ir_datasets>=0.3.2->python-terrier)
#   Downloading ijson-3.2.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (111 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 111.8/111.8 kB 9.6 MB/s eta 0:00:00
# Collecting pyautocorpus>=0.1.1 (from ir_datasets>=0.3.2->python-terrier)
#   Downloading pyautocorpus-0.1.12-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (379 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 379.9/379.9 kB 13.9 MB/s eta 0:00:00
# Collecting unlzw3>=0.2.1 (from ir_datasets>=0.3.2->python-terrier)
#   Downloading unlzw3-0.2.2-py3-none-any.whl (6.1 kB)
# Collecting cwl-eval>=1.0.10 (from ir_measures>=0.3.1->python-terrier)
#   Downloading cwl-eval-1.0.12.tar.gz (31 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->python-terrier) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->python-terrier) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->python-terrier) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->python-terrier) (2023.7.22)
# Collecting heapdict (from chest->python-terrier)
#   Downloading HeapDict-1.0.1-py3-none-any.whl (3.9 kB)
# Requirement already satisfied: wrapt<2,>=1.10 in /usr/local/lib/python3.10/dist-packages (from deprecated->python-terrier) (1.14.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->python-terrier) (2.1.3)
# Collecting multiset<3.0,>=2.0 (from matchpy->python-terrier)
#   Downloading multiset-2.1.1-py2.py3-none-any.whl (8.8 kB)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->python-terrier) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->python-terrier) (2023.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->python-terrier) (3.2.0)
# Requirement already satisfied: patsy>=0.5.2 in /usr/local/lib/python3.10/dist-packages (from statsmodels->python-terrier) (0.5.3)
# Requirement already satisfied: packaging>=21.3 in /usr/local/lib/python3.10/dist-packages (from statsmodels->python-terrier) (23.1)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4>=4.4.1->ir_datasets>=0.3.2->python-terrier) (2.4.1)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from patsy>=0.5.2->statsmodels->python-terrier) (1.16.0)
# Collecting cbor>=1.0.0 (from trec-car-tools>=2.5.4->ir_datasets>=0.3.2->python-terrier)
#   Downloading cbor-1.0.0.tar.gz (20 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: python-terrier, ir_measures, chest, wget, cwl-eval, warc3-wet-clueweb09, zlib-state, cbor
#   Building wheel for python-terrier (setup.py) ... done
#   Created wheel for python-terrier: filename=python_terrier-0.9.2-py3-none-any.whl size=112254 sha256=25cda22f144bc150d84ddfbbebcf0dde4ca558f8e08b594133fbae2110c681d4
#   Stored in directory: /root/.cache/pip/wheels/be/a8/0b/581cbefb648c84263ebf7bbfca2484e81d59f7732fd34ca386
#   Building wheel for ir_measures (setup.py) ... done
#   Created wheel for ir_measures: filename=ir_measures-0.3.3-py3-none-any.whl size=61183 sha256=f5e37ffcf8507ccd3471ccd5ef9a01fd588160e1ec29cf56281a3b7342e4edbc
#   Stored in directory: /root/.cache/pip/wheels/9f/0e/22/718279f23fef1673a4c5e433881c25080a6afaa147e007183e
#   Building wheel for chest (setup.py) ... done
#   Created wheel for chest: filename=chest-0.2.3-py3-none-any.whl size=7612 sha256=e6239a568cab66dc66db33eda237a65b4cc9000a8f940b804f8d295e64a34ac1
#   Stored in directory: /root/.cache/pip/wheels/88/cf/99/4773b31f855f9ecedc32a0ae400f7a4a3001b37c439b6d1a73
#   Building wheel for wget (setup.py) ... done
#   Created wheel for wget: filename=wget-3.2-py3-none-any.whl size=9655 sha256=c68a5645c8a59c5e51e47dff8b9508ebe86ac381c1dc53d656dd125e14ac788e
#   Stored in directory: /root/.cache/pip/wheels/8b/f1/7f/5c94f0a7a505ca1c81cd1d9208ae2064675d97582078e6c769
#   Building wheel for cwl-eval (setup.py) ... done
#   Created wheel for cwl-eval: filename=cwl_eval-1.0.12-py3-none-any.whl size=38068 sha256=894a30df0f0226a179fe79b8c66f410862bce052e8f61dcef0e3887e7ea389ea
#   Stored in directory: /root/.cache/pip/wheels/3d/c1/94/94a3e5379b1aa8fb7c7f1ad1956305d5edc98ef745b6067d87
#   Building wheel for warc3-wet-clueweb09 (setup.py) ... done
#   Created wheel for warc3-wet-clueweb09: filename=warc3_wet_clueweb09-0.2.5-py3-none-any.whl size=18919 sha256=4392cfb733a08edc0d4946e6407ff732283eb800136711e52c7f3ee8b1f36875
#   Stored in directory: /root/.cache/pip/wheels/1a/d7/91/7ffb991df87e62355d945745035470ba2616aa3d83a250b5f9
#   Building wheel for zlib-state (setup.py) ... done
#   Created wheel for zlib-state: filename=zlib_state-0.1.5-cp310-cp310-linux_x86_64.whl size=21168 sha256=d0b690aadf2c4a5d88572bb5786715722e4e2cf3ee50557533485ce6c5ef3530
#   Stored in directory: /root/.cache/pip/wheels/f8/7a/4e/8fa633b918bea99c052211d41caf8529707d7eae1099d5e5dd
#   Building wheel for cbor (setup.py) ... done
#   Created wheel for cbor: filename=cbor-1.0.0-cp310-cp310-linux_x86_64.whl size=53434 sha256=3d8d84990cb68d3156f83c77898e84a8c7b9b81d9edaaadb186c3db3ce03988d
#   Stored in directory: /root/.cache/pip/wheels/85/df/c9/b39e40eccaf76dbd218556639a6dc81562226f4c6a64902c85
# Successfully built python-terrier ir_measures chest wget cwl-eval warc3-wet-clueweb09 zlib-state cbor
# Installing collected packages: wget, warc3-wet-clueweb09, warc3-wet, typish, pyjnius, multiset, ijson, heapdict, cbor, zlib-state, unlzw3, trec-car-tools, pytrec_eval_terrier, pyautocorpus, nptyping, matchpy, lz4, dill, deprecated, cwl-eval, chest, ir_measures, inscriptis, ir_datasets, python-terrier
# Successfully installed cbor-1.0.0 chest-0.2.3 cwl-eval-1.0.12 deprecated-1.2.14 dill-0.3.7 heapdict-1.0.1 ijson-3.2.3 inscriptis-2.3.2 ir_datasets-0.5.5 ir_measures-0.3.3 lz4-4.3.2 matchpy-0.5.5 multiset-2.1.1 nptyping-1.4.4 pyautocorpus-0.1.12 pyjnius-1.5.0 python-terrier-0.9.2 pytrec_eval_terrier-0.5.5 trec-car-tools-2.6 typish-1.9.3 unlzw3-0.2.2 warc3-wet-0.2.3 warc3-wet-clueweb09-0.2.5 wget-3.2 zlib-state-0.1.5

# %%
import pyterrier as pt
pt.init()
# Out:
# terrier-assemblies 5.7 jar-with-dependencies not found, downloading to /root/.pyterrier...
# Done
# terrier-python-helper 0.0.7 jar not found, downloading to /root/.pyterrier...
# Done
# PyTerrier 0.9.2 has loaded Terrier 5.7 (built by craigm on 2022-11-10 18:30) and terrier-helper 0.0.7

# %%
pd_indexer = pt.DFIndexer("./pd_index")
indexref = pd_indexer.index(corpus_df["processed_text"].astype(str), corpus_df["docno"].astype(str))
# Out:
# /usr/local/lib/python3.10/dist-packages/pyterrier/index.py:628: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for column, value in meta_column[1].iteritems():

# %%
index = pt.IndexFactory.of(indexref)
print(index.getCollectionStatistics().toString())
# Out:
# Number of documents: 125516
# Number of terms: 188876
# Number of postings: 19833976
# Number of fields: 0
# Number of tokens: 32873281
# Field names: []
# Positions:   false

# %% [markdown]
# ### Use the text in title in the queries convert to TF-IDF.

# %%
import xml.etree.ElementTree as ET
import pandas as pd

# Define the path to the query file
path_query_file = "/content/extracted_files/FIRE_Dataset_EN_2010/en.topics.76-125.2010.txt"

# Read the query file into a DataFrame
columns = ["qid", "query"]
queries = []

tree = ET.parse(path_query_file)
root = tree.getroot()

for topic in root.findall('top'):
    topic_number = topic.find('num').text
    title = topic.find('title').text
    queries.append([topic_number, preprocess(title)])

query_df = pd.DataFrame(queries, columns=columns)

query_df
# Out:
#     qid                                              query
# 0    76                                 clash gurjar meena
# 1    77                         attack hezbollah guerrilla
# 2    78            conflict advani singhal ram mandir issu
# 3    79                     build road china mount everest
# 4    80             babri masjid demolit case start advani
# 5    81  problem relat immun programm japanes enceph india
# 6    82             propos bu servic srinagar muzaffarabad
# 7    83  elect campaign laloo prasad yadav ram vila paswan
# 8    84                    brinda karat alleg swami ramdev
# 9    85  abu salem accus mumbai bomb blast case jail cu...
# 10   86                        privat mumbai delhi airport
# 11   87  discuss manmohan singh pervez musharraf regard...
# 12   88  popular protest arrest accus shankar raman mur...
# 13   89               involv congress minist oil food scam
# 14   90                     indian repres visit bangladesh
# 15   91               alleg financi corrupt pratibha patil
# 16   92                        activ tamil tiger sri lanka
# 17   93                take bribe rais question parliament
# 18   94             indian navi accus leak classifi inform
# 19   95                        racism row big brother show
# 20   96                              pramod mahajan killer
# 21   97  quarrel ambani brother regard ownership relian...
# 22   98          india dismiss china claim arunach pradesh
# 23   99                     laloo prasad yadav fodder scam
# 24  100                  monica bedi passport forgeri case
# 25  101                 drug parti pramod mahajan bungalow
# 26  102              pakistani cricket involv dope scandal
# 27  103  bilater problem surround baglihar hydro electr...
# 28  104          jaya bachchan sack rajya sabha membership
# 29  105                       taj heritag corridor scandal
# 30  106                    ban taslima nasreen novel shame
# 31  107  furor releas cd contain anti muslim sentiment ...
# 32  108                                   greater nagaland
# 33  109                 new polit parti form raj thackeray
# 34  110                     sino indian relat border trade
# 35  111                                danc bar ban mumbai
# 36  112                  link gutkha manufactur underworld
# 37  113                             polit clash bangladesh
# 38  114               investig arm scandal defenc ministri
# 39  115                              serial blast varanasi
# 40  116                      encount specialist daya nayak
# 41  117                      controversi land kalinganagar
# 42  118                           terrorist strike ayodhya
# 43  119                              taj mahal controversi
# 44  120                  sex cd scandal involv anara gupta
# 45  121                            blast samjhauta express
# 46  122                                sanjay dutt surrend
# 47  123                                death yasser arafat
# 48  124                sale illeg drug variou indian state
# 49  125                                  attack lal masjid

# %%
br = pt.BatchRetrieve(index, wmodel="TF_IDF")
res = br.transform(query_df)
res
# Out:
#        qid   docid                               docno  rank      score  \
# 0       76   99361   1070603_nation_story_7869357.utf8     0  20.186933
# 1       76   99688   1070611_nation_story_7906812.utf8     1  16.385560
# 2       76  100514   1070602_nation_story_7865940.utf8     2  13.973796
# 3       76   70248   1060912_nation_story_6733766.utf8     3  12.765150
# 4       76  101971   1070602_nation_story_7865944.utf8     4  12.434667
# ...    ...     ...                                 ...   ...        ...
# 49995  125   61577           1060225_sports_index.utf8   995   3.938441
# 49996  125   91159          1070608_opinion_index.utf8   996   3.938441
# 49997  125   29317   1050513_nation_story_4733846.utf8   997   3.938288
# 49998  125   87630  1070430_foreign_story_7715573.utf8   998   3.934818
# 49999  125   11336  1051111_foreign_story_5463733.utf8   999   3.932554
#
#                     query
# 0      clash gurjar meena
# 1      clash gurjar meena
# 2      clash gurjar meena
# 3      clash gurjar meena
# 4      clash gurjar meena
# ...                   ...
# 49995   attack lal masjid
# 49996   attack lal masjid
# 49997   attack lal masjid
# 49998   attack lal masjid
# 49999   attack lal masjid
#
# [50000 rows x 6 columns]
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def value_plot(df, y, figscale=1):
#   from matplotlib import pyplot as plt
#   df[y].plot(kind='line', figsize=(8 * figscale, 4 * figscale), title=y)
#   plt.gca().spines[['top', 'right']].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = value_plot(res, *['docid'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def value_plot(df, y, figscale=1):
#   from matplotlib import pyplot as plt
#   df[y].plot(kind='line', figsize=(8 * figscale, 4 * figscale), title=y)
#   plt.gca().spines[['top', 'right']].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = value_plot(res, *['rank'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def value_plot(df, y, figscale=1):
#   from matplotlib import pyplot as plt
#   df[y].plot(kind='line', figsize=(8 * figscale, 4 * figscale), title=y)
#   plt.gca().spines[['top', 'right']].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = value_plot(res, *['score'], **{})
# chart
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def histogram(df, colname, num_bins=20, figscale=1):
#   from matplotlib import pyplot as plt
#   df[colname].plot(kind='hist', bins=num_bins, title=colname, figsize=(8*figscale, 4*figscale))
#   plt.gca().spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = histogram(res, *['docid'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def histogram(df, colname, num_bins=20, figscale=1):
#   from matplotlib import pyplot as plt
#   df[colname].plot(kind='hist', bins=num_bins, title=colname, figsize=(8*figscale, 4*figscale))
#   plt.gca().spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = histogram(res, *['rank'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def histogram(df, colname, num_bins=20, figscale=1):
#   from matplotlib import pyplot as plt
#   df[colname].plot(kind='hist', bins=num_bins, title=colname, figsize=(8*figscale, 4*figscale))
#   plt.gca().spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = histogram(res, *['score'], **{})
# chart
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def scatter_plots(df, colname_pairs, figscale=1, alpha=.8):
#   from matplotlib import pyplot as plt
#   plt.figure(figsize=(len(colname_pairs) * 6 * figscale, 6 * figscale))
#   for plot_i, (x_colname, y_colname) in enumerate(colname_pairs, start=1):
#     ax = plt.subplot(1, len(colname_pairs), plot_i)
#     df.plot(kind='scatter', x=x_colname, y=y_colname, s=(32 * figscale), alpha=alpha, ax=ax)
#     ax.spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = scatter_plots(res, *[[['docid', 'rank'], ['rank', 'score']]], **{})
# chart

# %% [markdown]
# ### Perform retrieval and perform evaluation using:
# * Precision@10
# * Recall@10
# * F1-score

# %% [markdown]
# **Ground Truth**

# %%
q_path=("/content/extracted_files/FIRE_Dataset_EN_2010/en.qrels.76-125.2010.txt")
qrels = pt.io.read_qrels(q_path)
qrels
# Out:
#        qid                                docno  label
# 0       76    1040901_nation_story_3702283.utf8      0
# 1       76   1040901_opinion_story_3675790.utf8      0
# 2       76    1040902_nation_story_3707291.utf8      0
# 3       76   1040904_opinion_story_3713095.utf8      0
# 4       76  1040908_calcutta_story_3729202.utf8      0
# ...    ...                                  ...    ...
# 15130  125    1070914_nation_story_8315528.utf8      0
# 15131  125    1070914_nation_story_8315898.utf8      0
# 15132  125    1070918_nation_story_8329783.utf8      0
# 15133  125   1070921_foreign_story_8343703.utf8      0
# 15134  125  1070922_calcutta_story_8345507.utf8      0
#
# [15135 rows x 3 columns]

# %% [markdown]
# **Query wise, Evaluation metric values are:**

# %%
eval = pt.Utils.evaluate(res,qrels,metrics=["P_10","recall_10"],perquery=True)
eval_df = pd.DataFrame(eval).T
eval_df['F1_10'] = 2 * (eval_df['P_10'] * eval_df['recall_10']) / (eval_df['P_10'] + eval_df['recall_10'])
eval_df['F1_10'].fillna(0, inplace=True)
eval_df
# Out:
#      P_10  recall_10     F1_10
# 76    0.4   1.000000  0.571429
# 77    0.0   0.000000  0.000000
# 78    0.3   1.000000  0.461538
# 79    0.3   0.750000  0.428571
# 80    0.3   0.375000  0.333333
# 81    0.2   0.333333  0.250000
# 82    0.4   0.173913  0.242424
# 83    0.0   0.000000  0.000000
# 84    0.3   1.000000  0.461538
# 85    0.5   0.227273  0.312500
# 86    0.2   0.285714  0.235294
# 87    0.3   0.333333  0.315789
# 88    0.4   0.181818  0.250000
# 89    0.7   0.148936  0.245614
# 90    0.0   0.000000  0.000000
# 91    0.6   0.500000  0.545455
# 92    0.3   0.078947  0.125000
# 93    0.4   0.210526  0.275862
# 94    0.8   0.320000  0.457143
# 95    0.6   0.545455  0.571429
# 96    0.0   0.000000  0.000000
# 97    0.3   0.136364  0.187500
# 98    0.3   0.600000  0.400000
# 99    0.1   0.333333  0.153846
# 100   0.5   0.238095  0.322581
# 101   0.3   0.230769  0.260870
# 102   0.1   0.058824  0.074074
# 103   0.2   0.285714  0.235294
# 104   0.2   0.250000  0.222222
# 105   0.3   0.230769  0.260870
# 106   0.4   1.000000  0.571429
# 107   0.9   0.642857  0.750000
# 108   0.5   0.454545  0.476190
# 109   0.4   0.400000  0.400000
# 110   0.1   0.090909  0.095238
# 111   0.8   0.500000  0.615385
# 112   0.5   0.294118  0.370370
# 113   0.4   0.285714  0.333333
# 114   0.1   0.125000  0.111111
# 115   0.3   0.157895  0.206897
# 116   0.7   0.700000  0.700000
# 117   0.0   0.000000  0.000000
# 118   0.3   0.300000  0.300000
# 119   0.3   0.428571  0.352941
# 120   0.6   0.500000  0.545455
# 121   0.4   0.190476  0.258065
# 122   0.9   0.450000  0.600000
# 123   0.8   0.421053  0.551724
# 124   0.0   0.000000  0.000000
# 125   0.3   0.230769  0.260870

# %% [markdown]
#  **Thus, Overall evaluation scores are as follow:**

# %%
eval = pt.Utils.evaluate(res,qrels,metrics=["P_10","recall_10"])
p = eval['P_10']
r = eval['recall_10']
eval['F1_10'] = 2*p*r/(p+r)

eval_df = pd.DataFrame([eval])
eval_df
# Out:
#    P_10  recall_10     F1_10
# 0  0.36   0.340001  0.349715
